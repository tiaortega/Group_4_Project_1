# %%
import requests
import json
# %matplotlib notebook

from pprint import pprint
import pandas as pd
import numpy as np
from datetime import datetime
import os

import matplotlib.pyplot as plt

fileTLM1_to_load = "Resources/Texas Labor Market CES Data.csv"

# %%
TLM1_data = pd.read_csv(fileTLM1_to_load)
TLM1_data.head()
# Out:
#                                 Industry      20-Jul      20-Jun      19-Jul  \
# 0                          TOTAL NONFARM  12,087,800  12,145,700  12,765,800
# 1                          TOTAL PRIVATE  10,231,200  10,254,600  10,865,900
# 2                        GOODS PRODUCING   1,807,600   1,815,800   1,942,200
# 3    Mining and Logging (NAICS 21, 1133)     191,500     192,700     250,700
# 4     Oil and Gas Extraction (NAICS 211)      70,500      69,300      77,800
#
#   Monthly Change Monthly % Change Annual Change Annual\n% Change Unnamed: 8
# 0        -57,900           -0.50%      -678,000           -5.30%        NaN
# 1        -23,400           -0.20%      -634,700           -5.80%        NaN
# 2         -8,200           -0.50%      -134,600           -6.90%        NaN
# 3         -1,200           -0.60%       -59,200          -23.60%        NaN
# 4          1,200            1.70%        -7,300           -9.40%        NaN

# %%
industry =[-35.80, -30.50, -0.10, -0.40, 6.60, 15.70 ]
x_axis = np.arange(len(industry))
x_axis
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
fig1 = plt.figure()
plt.bar(x=x_axis, height=industry, color='red', alpha=0.5, align='center',)

plt.xticks(x_axis, ["Support Activities\n for Mining", "Amusement, \nGambling, and \nRecreation", "Financial Activities", "General Merchandise\n Stores",
                    "Building Material &\n Garden Equipment &\n Supplies", "Couriers and\n Messengers"], rotation=90)
plt.xlim(-0.95, len(x_axis)+0.10)
plt.ylim(-40, max(industry)*1.1)

plt.tick_params("x", labelsize=10)

plt.title("Annual % Change By Industry During Covid-19")
plt.xlabel("Industry")
plt.ylabel("Annual Percent Change (%)")
plt.hlines(0, min(industry), max(industry), alpha=.09)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.tight_layout()

# %%
output_path = os.path.join(".", "Images", "Annual_Change_by_Industry.png")
plt.savefig(output_path)

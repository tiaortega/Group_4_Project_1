# %%
import requests
import json
# %matplotlib notebook

from pprint import pprint
import pandas as pd
import numpy as np
from datetime import datetime
import os
import random
import matplotlib.pyplot as plt
from itertools import cycle, islice

# %%
pos_test = "./Resources/% positive tests by month.csv"

# %%
PTBM_data = pd.read_csv(pos_test)
PTBM_data.head()
# Out:
#       tx_pos     ny_pos    tx_total    ny_total  tx_per_pos  ny_per_pos
# 0     476756   12819520     6610184    40970160    7.212447   31.289895
# 1   14258160  186853290   149992050   488777160    9.505944   38.228728
# 2   44350553  331497601   609606010  1356760787    7.275281   24.433018
# 3   89954610  345404760  1225471050  2722097280    7.340411   12.688921
# 4  282763369  388881143  2645494647  4733082666   10.688488    8.216234

# %%
# tx = PTBM_data['tx_pos'].min()
# tx

# %%
# ny = PTBM_data['ny_pos'].min()
# ny

# %%
# tx = PTBM_data['tx_total'].min()
# tx

# %%
# ny = PTBM_data['ny_total'].min()
# ny

# %%
tx = PTBM_data['tx_per_pos'].sum()
tx
# Out:
# 66.44636327485266

# %%
ny = PTBM_data['ny_per_pos'].sum()
ny
# Out:
# 125.7643730831919

# %%
PTBM_data.head()
# Out:
#       tx_pos     ny_pos    tx_total    ny_total  tx_per_pos  ny_per_pos
# 0     476756   12819520     6610184    40970160    7.212447   31.289895
# 1   14258160  186853290   149992050   488777160    9.505944   38.228728
# 2   44350553  331497601   609606010  1356760787    7.275281   24.433018
# 3   89954610  345404760  1225471050  2722097280    7.340411   12.688921
# 4  282763369  388881143  2645494647  4733082666   10.688488    8.216234

# %%
tx_ny_covid19 = ["Texas", "New York"]
tx_ny_values = [66.44636327485266, 125.7643730831919]
x_axis = len(tx_ny_covid19)
plt.bar(x=tx_ny_covid19,height=tx_ny_values)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %%
plt.title("Texas vs New York in Positive Covid-19 Testing")
plt.xlabel(" States")
plt.ylabel("Positive Testing (%)")
# Out:
# Text(0, 0.5, 'Positive Testing (%)')

# %%
output_path = os.path.join("Images", "TXvsNY.png")
plt.savefig(output_path)
# Out:
# <img src="data:image/png;base64,..." width="640">

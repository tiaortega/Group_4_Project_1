# %%
import requests
import json
from config import api_key
from config import g_key
from pprint import pprint
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

import gmaps

# Google developer API key
from config import g_key

# Access maps with unique API key
gmaps.configure(api_key=g_key)

query_tx_url="https://api.covidtracking.com/v1/states/tx/daily.csv"
query_ny_url="https://api.covidtracking.com/v1/states/ny/daily.csv"
query_all_url="https://api.covidtracking.com/v1/states/daily.csv"

fileTLM1_to_load = "Resources/Texas Labor Market CES Data.csv"
fileTLM2_to_load = "Resources/Texas Labor Market Indicators.csv"
fileTLM3_to_load = "Resources/Texas Labor Market LAUS Data.csv"
fileTLM4_to_load = "Resources/TXCountiesUnemployRateChanges.csv"
latlong_to_load = "Resources/CountyLatLong.csv"

# %%
covid_tx_df = pd.read_csv(query_tx_url)
covid_tx_df
# Out:
#          date state  positive   negative  pending  totalTestResults  \
# 0    20200918    TX    682241  4762560.0      NaN           5444801
# 1    20200917    TX    678819  4666357.0      NaN           5345176
# 2    20200916    TX    674772  4624848.0      NaN           5299620
# 3    20200915    TX    668746  4578796.0      NaN           5247542
# 4    20200914    TX    663445  4549802.0      NaN           5213247
# ..        ...   ...       ...        ...      ...               ...
# 194  20200308    TX         8        NaN      NaN                 8
# 195  20200307    TX         8        NaN      NaN                 8
# 196  20200306    TX         5        NaN      NaN                 5
# 197  20200305    TX         1        NaN      NaN                 1
# 198  20200304    TX         1        NaN      NaN                 1
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 0                   3172.0                     NaN          1107.0
# ...

# %%
TLM1_data = pd.read_csv(fileTLM1_to_load)
TLM1_data.head()
# Out:
#                                 Industry      20-Jul      20-Jun      19-Jul  \
# 0                          TOTAL NONFARM  12,087,800  12,145,700  12,765,800
# 1                          TOTAL PRIVATE  10,231,200  10,254,600  10,865,900
# 2                        GOODS PRODUCING   1,807,600   1,815,800   1,942,200
# 3    Mining and Logging (NAICS 21, 1133)     191,500     192,700     250,700
# 4     Oil and Gas Extraction (NAICS 211)      70,500      69,300      77,800
#
#   Monthly Change Monthly % Change Annual Change Annual\n% Change Unnamed: 8
# 0        -57,900           -0.50%      -678,000           -5.30%        NaN
# 1        -23,400           -0.20%      -634,700           -5.80%        NaN
# 2         -8,200           -0.50%      -134,600           -6.90%        NaN
# 3         -1,200           -0.60%       -59,200          -23.60%        NaN
# 4          1,200            1.70%        -7,300           -9.40%        NaN

# %%
TLM2_data = pd.read_csv(fileTLM2_to_load)
TLM2_data.head()
# Out:
#      Date    Texas     U.S.  Unnamed: 3 Unnamed: 4
# 0  10-Jan  $21.31   $22.51          NaN        NaN
# 1  10-Feb  $21.41   $22.57          NaN        NaN
# 2  10-Mar  $21.31   $22.48          NaN        NaN
# 3  10-Apr  $21.42   $22.53          NaN        NaN
# 4  10-May  $21.39   $22.60          NaN        NaN

# %%
TLM3_data = pd.read_csv(fileTLM3_to_load)
TLM3_data.head()
# Out:
#            Metro Areas Civilian Labor Force\nJuly\n2020 Employed\nJuly\n2020  \
# 0        United States                      161,374,000          144,492,000
# 1                Texas                       13,846,028           12,705,927
# 2              Abilene                           77,159               72,572
# 3             Amarillo                          125,356              118,920
# 4    Austin-Round Rock                        1,225,085            1,143,143
#
#   Unemployed\nJuly\n2020  Rate\nJuly\n2020 Civilian Labor Force\nJune\n2020  \
# 0             16,882,000              10.5                      160,883,000
# 1              1,140,101               8.2                       13,804,456
# 2                  4,587               5.9                           76,433
# 3                  6,436               5.1                          125,167
# 4                 81,942               6.7                        1,215,025
#
# ...

# %%
covid_ny_df = pd.read_csv(query_ny_url)
covid_ny_df
# Out:
#          date state  positive  negative  pending  totalTestResults  \
# 0    20200918    NY    448052   9263595      NaN           9711647
# 1    20200917    NY    447262   9174658      NaN           9621920
# 2    20200916    NY    446366   9084050      NaN           9530416
# 3    20200915    NY    445714   9009615      NaN           9455329
# 4    20200914    NY    444948   8936703      NaN           9381651
# ..        ...   ...       ...       ...      ...               ...
# 194  20200308    NY       105        92      NaN               197
# 195  20200307    NY        76        92    236.0               168
# 196  20200306    NY        33        92    236.0               125
# 197  20200305    NY        22        76     24.0                98
# 198  20200304    NY         6        48     24.0                54
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 0                    478.0                 89995.0           141.0
# ...

# %%
covid_all_df = pd.read_csv(query_all_url)
covid_all_df
# Out:
#            date state  positive   negative  pending  totalTestResults  \
# 0      20200918    AK    7587.0   410706.0      NaN          418293.0
# 1      20200918    AL  142863.0   910192.0      NaN         1039010.0
# 2      20200918    AR   74082.0   794097.0      NaN          866435.0
# 3      20200918    AS       0.0     1571.0      NaN            1571.0
# 4      20200918    AZ  212942.0  1149377.0      NaN         1362319.0
# ...         ...   ...       ...        ...      ...               ...
# 11125  20200124    WA       0.0        0.0      NaN               NaN
# 11126  20200123    MA       NaN        NaN      NaN               2.0
# 11127  20200123    WA       0.0        0.0      NaN               NaN
# 11128  20200122    MA       NaN        NaN      NaN               1.0
# 11129  20200122    WA       0.0        0.0      NaN               NaN
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# ...

# %%
covid_tx_df['date'] = pd.to_datetime(covid_tx_df['date'], format='%Y%m%d')
covid_ny_df['date'] = pd.to_datetime(covid_ny_df['date'], format='%Y%m%d')
covid_all_df['date'] = pd.to_datetime(covid_all_df['date'], format='%Y%m%d')

# %%
covid_tx_df
# Out:
#           date state  positive   negative  pending  totalTestResults  \
# 0   2020-09-18    TX    682241  4762560.0      NaN           5444801
# 1   2020-09-17    TX    678819  4666357.0      NaN           5345176
# 2   2020-09-16    TX    674772  4624848.0      NaN           5299620
# 3   2020-09-15    TX    668746  4578796.0      NaN           5247542
# 4   2020-09-14    TX    663445  4549802.0      NaN           5213247
# ..         ...   ...       ...        ...      ...               ...
# 194 2020-03-08    TX         8        NaN      NaN                 8
# 195 2020-03-07    TX         8        NaN      NaN                 8
# 196 2020-03-06    TX         5        NaN      NaN                 5
# 197 2020-03-05    TX         1        NaN      NaN                 1
# 198 2020-03-04    TX         1        NaN      NaN                 1
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 0                   3172.0                     NaN          1107.0
# ...

# %%
covid_ny_df
# Out:
#           date state  positive  negative  pending  totalTestResults  \
# 0   2020-09-18    NY    448052   9263595      NaN           9711647
# 1   2020-09-17    NY    447262   9174658      NaN           9621920
# 2   2020-09-16    NY    446366   9084050      NaN           9530416
# 3   2020-09-15    NY    445714   9009615      NaN           9455329
# 4   2020-09-14    NY    444948   8936703      NaN           9381651
# ..         ...   ...       ...       ...      ...               ...
# 194 2020-03-08    NY       105        92      NaN               197
# 195 2020-03-07    NY        76        92    236.0               168
# 196 2020-03-06    NY        33        92    236.0               125
# 197 2020-03-05    NY        22        76     24.0                98
# 198 2020-03-04    NY         6        48     24.0                54
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 0                    478.0                 89995.0           141.0
# ...

# %%
covid_all_df
# Out:
#             date state  positive   negative  pending  totalTestResults  \
# 0     2020-09-18    AK    7587.0   410706.0      NaN          418293.0
# 1     2020-09-18    AL  142863.0   910192.0      NaN         1039010.0
# 2     2020-09-18    AR   74082.0   794097.0      NaN          866435.0
# 3     2020-09-18    AS       0.0     1571.0      NaN            1571.0
# 4     2020-09-18    AZ  212942.0  1149377.0      NaN         1362319.0
# ...          ...   ...       ...        ...      ...               ...
# 11125 2020-01-24    WA       0.0        0.0      NaN               NaN
# 11126 2020-01-23    MA       NaN        NaN      NaN               2.0
# 11127 2020-01-23    WA       0.0        0.0      NaN               NaN
# 11128 2020-01-22    MA       NaN        NaN      NaN               1.0
# 11129 2020-01-22    WA       0.0        0.0      NaN               NaN
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# ...

# %%
covid_tx_df.set_index('date')
# Out:
#            state  positive   negative  pending  totalTestResults  \
# date
# 2020-09-18    TX    682241  4762560.0      NaN           5444801
# 2020-09-17    TX    678819  4666357.0      NaN           5345176
# 2020-09-16    TX    674772  4624848.0      NaN           5299620
# 2020-09-15    TX    668746  4578796.0      NaN           5247542
# 2020-09-14    TX    663445  4549802.0      NaN           5213247
# ...          ...       ...        ...      ...               ...
# 2020-03-08    TX         8        NaN      NaN                 8
# 2020-03-07    TX         8        NaN      NaN                 8
# 2020-03-06    TX         5        NaN      NaN                 5
# 2020-03-05    TX         1        NaN      NaN                 1
# 2020-03-04    TX         1        NaN      NaN                 1
#
#             hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# date
# 2020-09-18                 3172.0                     NaN          1107.0
# ...

# %%
covid_ny_df.set_index('date')
# Out:
#            state  positive  negative  pending  totalTestResults  \
# date
# 2020-09-18    NY    448052   9263595      NaN           9711647
# 2020-09-17    NY    447262   9174658      NaN           9621920
# 2020-09-16    NY    446366   9084050      NaN           9530416
# 2020-09-15    NY    445714   9009615      NaN           9455329
# 2020-09-14    NY    444948   8936703      NaN           9381651
# ...          ...       ...       ...      ...               ...
# 2020-03-08    NY       105        92      NaN               197
# 2020-03-07    NY        76        92    236.0               168
# 2020-03-06    NY        33        92    236.0               125
# 2020-03-05    NY        22        76     24.0                98
# 2020-03-04    NY         6        48     24.0                54
#
#             hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# date
# 2020-09-18                  478.0                 89995.0           141.0
# ...

# %%
covid_all_df.set_index('date')
# Out:
#            state  positive   negative  pending  totalTestResults  \
# date
# 2020-09-18    AK    7587.0   410706.0      NaN          418293.0
# 2020-09-18    AL  142863.0   910192.0      NaN         1039010.0
# 2020-09-18    AR   74082.0   794097.0      NaN          866435.0
# 2020-09-18    AS       0.0     1571.0      NaN            1571.0
# 2020-09-18    AZ  212942.0  1149377.0      NaN         1362319.0
# ...          ...       ...        ...      ...               ...
# 2020-01-24    WA       0.0        0.0      NaN               NaN
# 2020-01-23    MA       NaN        NaN      NaN               2.0
# 2020-01-23    WA       0.0        0.0      NaN               NaN
# 2020-01-22    MA       NaN        NaN      NaN               1.0
# 2020-01-22    WA       0.0        0.0      NaN               NaN
#
#             hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# date
# 2020-09-18                   36.0                     NaN             NaN
# ...

# %%
fileTLM4_to_load
TLM4_data = pd.read_csv(fileTLM4_to_load)
TLM4_data.head()
# Out:
#        county  20200701  20200601  20190701  Monthly Change  Annual Change
# 0    Anderson       6.1       6.3       3.2            -0.2            2.9
# 1     Andrews       9.0       9.7       2.5            -0.7            6.5
# 2    Angelina       8.2       8.6       4.4            -0.4            3.8
# 3     Aransas       8.8       8.9       4.6            -0.1            4.2
# 4      Archer       5.5       5.9       3.1            -0.4            2.4

# %%
import gmaps
import gmaps.datasets

#gmaps.configure(api_key='AIzaSyBI9uyq77-SfK8MzJF921o9lYolFwTgO_w')

TXCounty_df = pd.read_csv(latlong_to_load)
TXCounty_df = TXCounty_df.drop_duplicates(subset='county', keep="first")
TXCounty_df['county'] = TXCounty_df['county'].str.strip()

# %%
TLM4_data = TLM4_data.drop_duplicates(subset='county', keep="first")
TLM4_data_df=TLM4_data[["county", "Annual Change"]]
TLM4_data_df.shape
TLM4_data_df['county'] = TLM4_data_df['county'].str.strip()
# Out:
# <ipython-input-17-acfd1d869e95>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TLM4_data_df['county'] = TLM4_data_df['county'].str.strip()

# %%
TXCounty_df.columns
# Out:
# Index(['latitude', 'longitude', 'county'], dtype='object')

# %%
tx_unique = TXCounty_df['county'].unique()
tlm4_unique = TLM4_data_df['county'].unique()

np.setdiff1d(tx_unique, tlm4_unique, assume_unique=True)
# Out:
# array(['De Witt', 'Mclennan', nan], dtype=object)

# %%
merge_table = pd.merge(TXCounty_df, TLM4_data_df, how='left', on='county')
merge_table
# Out:
#      latitude  longitude    county  Annual Change
# 0       32.05     -95.50  Anderson            2.9
# 1       32.32    -102.54   Andrews            6.5
# 2       31.33     -94.72  Angelina            3.8
# 3       28.07     -97.03   Aransas            4.2
# 4       33.59     -98.62    Archer            2.4
# ..        ...        ...       ...            ...
# 251     32.96    -102.83    Yoakum           10.1
# 252     33.19     -98.74     Young            2.3
# 253     27.19     -99.32    Zapata            6.9
# 254     28.94     -99.61    Zavala            6.4
# 255     33.14     -96.81       NaN            NaN
#
# [256 rows x 4 columns]

# %%
from config import g_key

# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
fig = gmaps.figure()
fig1 = gmaps.figure()

# display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a marker layer using our coordinates
marker_locations = gmaps.marker_layer(merge_table[['latitude','longitude']])
merge_table['Annual Change'].round(1)

# # Add the layer to the map
fig.add_layer(marker_locations)

# # display the figure with the newly added layer
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{county}</dd>
<dt>Annual Change</dt><dd>{Annual Change}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
merge_info = [info_box_template.format(**row) for index, row in merge_table.iterrows()]
marker_locations = merge_table[['latitude','longitude']]

# %%
markers = gmaps.marker_layer(marker_locations, info_box_content = merge_info)

# Add the layer to the map
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a marker layer using our coordinates
markers = gmaps.marker_layer(merge_table[['latitude','longitude']])

# # Add the layer to the map
fig.add_layer(markers)

# # display the figure with the newly added layer
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
merge_table['Annual Change'] = merge_table['Annual Change'] - min(merge_table['Annual Change'])

# %%
heat_layer = gmaps.heatmap_layer(marker_locations, weights=merge_table['Annual Change'], dissipating=False, max_intensity=15, point_radius=0.5)

# %%
max(merge_table['Annual Change'])
# Out:
# 12.9

# %%
# Add the layer to the map
fig1.add_layer(heat_layer)

# Display figure
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))
